# %%
import numpy as np
import pandas as pd
import spacy
from spacy import displacy

# %%
df = pd.read_json('../gg2013.json')
df.head()
# Out:
#                                                 text  \
# 0             JLo's dress! #eredcarpet #GoldenGlobes
# 1  What's making Sofia Vergara's boobs stay like ...
# 2  RT @FabSugar: Kerry Washington is EVERYTHING. ...
# 3     Anne Hathaway has got me living. #GoldenGlobes
# 4  Jennifer Lopez's lace dress? Thoughts? #Golden...
#
#                                                 user                  id  \
# 0      {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 1    {'screen_name': 'theAmberShow', 'id': 14648726}  290620657887219713
# 2        {'screen_name': 'SweetyPW', 'id': 35498686}  290620657828524032
# 3  {'screen_name': '_NicoleEdwards', 'id': 144430...  290620657799159809
# 4  {'screen_name': 'lolaogunnaike', 'id': 134953223}  290620657778188288
#
#          timestamp_ms
# 0 2013-01-14 00:45:38
# 1 2013-01-14 00:45:38
# 2 2013-01-14 00:45:38
# 3 2013-01-14 00:45:38
# 4 2013-01-14 00:45:38

# %%
df1 = df[200:250]
print(df1)
# Out:
#                                                   text  \
# 200  Oohlala! Kate Hudson kills it in black and gol...
# 201  RT @RPLife: :) RT @popsugar: This guy! #Robert...
# 202  How did I not realize Hugh Jackman was Austral...
# 203  anne hathaway. chanel. prechus. prechus. #gold...
# 204  RT @popsugar: .@taylorswift13 looks gorgeous i...
# 205        #GoldenGlobes Adele se veía Hermosa que Voz
# 206  ANNE HATHAWAY!!!!!!!!!!! GOOD LORD OF MERCY!!!...
# 207  Hugh Jackman compared singing in front of a ca...
# 208  "They look spectacular in these dresses, but t...
# 209  How long until lower third television graphics...
# 210  Can't get enough of Kerry Washington's choppy ...
# 211  Oh Anne, that's too old of a look for you...#G...
# 212  RT @TheCut: Gretchen Weiners: "Stop trying to ...
# 213  No entiendo la gracia de la manicam... #Golden...
# 214  #GoldenGlobes Amo a Anne Hathaway se ve hermos...
# 215  I'll tell ya who's wearing on me: actors at th...
# ...

# %%
for i in range(5):
    print(df.iloc[i]["text"])
# Out:
# JLo's dress! #eredcarpet #GoldenGlobes
# What's making Sofia Vergara's boobs stay like that? Magic? Witchcraft? #GoldenGlobes
# RT @FabSugar: Kerry Washington is EVERYTHING. Dying over her Miu Miu gown! @goldenglobes #goldenglobes http://t.co/3feH7MvO
# Anne Hathaway has got me living. #GoldenGlobes
# Jennifer Lopez's lace dress? Thoughts? #GoldenGlobes

# %%
# #redcarpet or containing "red carpet" most likely to have info on dressed
df[df['text'].str.contains("red carpet|#redcarpet|carpet", case=False)]
# Out:
#                                                      text  \
# 0                  JLo's dress! #eredcarpet #GoldenGlobes
# 5       Podrán criticar a #Adele de su moda y su maniq...
# 11      Jennifer Lopez's dress is jaw droppingly amazi...
# 12      Jessica Alba is absolutely flawless, omg❤ #red...
# 13      Werk @kerrywashington Stunning!!! #GoldenGlobe...
# ...                                                   ...
# 174463  RT @redcarpet: 2013 Golden Globes Winners: The...
# 174471  RT @redcarpet: 2013 Golden Globes Winners: The...
# 174545  I'm not all into red carpet fashion, but Miche...
# 174598  RT @RPLife: 2 Red Carpet HQs added and maybe m...
# 174607  Jennifer Lawrence vs. Zooey Deschanel: It's th...
#
#                                                      user                  id  \
# 0           {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 5          {'screen_name': 'SabyOnford', 'id': 404554221}  290620657719455745
# ...

# %%
# can we remove tweets not in English?
from spacy_langdetect import LanguageDetector as langdetect
textEx = df.iloc[0]["text"]
lang = langdetect("textEx")
print(lang)

# %%
from spacy_langdetect import LanguageDetector
nlp = spacy.load('en_core_web_md')
nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)
text = 'This is an english text.'
doc = nlp(text)
# document level language detection. Think of it like average language of the document!
print(doc._.language)
# sentence level language detection
for sent in doc.sents:
   print(sent, sent._.language)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-fbbfe59ab3d8> in <module>
#       1 from spacy_langdetect import LanguageDetector
# ----> 2 nlp = spacy.load('en_core_web_md')
#       3 nlp.add_pipe(LanguageDetector(), name='language_detector', last=True)
#       4 text = 'This is an english text.'
#       5 doc = nlp(text)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
#      29         warnings.warn(Warnings.W001.format(path=depr_path), DeprecationWarning)
# ---> 30     return util.load_model(name, **overrides)
#      31
#      32
#
# ~/opt/anaconda3/lib/python3.8/site-packages/spacy/util.py in load_model(name, **overrides)
#     173     elif hasattr(name, "exists"):  # Path or Path-like to model data
# ...

# %%
# get rid of #goldenglobes because every tweet has it
df['text'] = df['text'].str.replace('#goldenglobes', '', case=False)
df
# Out:
#                                                      text  \
# 0                               JLo's dress! #eredcarpet
# 1       What's making Sofia Vergara's boobs stay like ...
# 2       RT @FabSugar: Kerry Washington is EVERYTHING. ...
# 3                       Anne Hathaway has got me living.
# 4                 Jennifer Lopez's lace dress? Thoughts?
# ...                                                   ...
# 174638  RT @authorViviAnna: I was sad that Mandy Patin...
# 174639  RT @_ItzelMartinez_: Jennifer Lawrence aceptan...
# 174640  Golden Globes, lots of fashion messes...but gl...
# 174641  Did they have mug shots at the golden globes?!...
# 174642  Says @BenAffleck: "I also didn't get the Actin...
#
#                                                      user                  id  \
# 0           {'screen_name': 'Dozaaa_xo', 'id': 557374298}  290620657987887104
# 1         {'screen_name': 'theAmberShow', 'id': 14648726}  290620657887219713
# ...

# %%
df2 = df[df['text'].str.contains("best actor", case=False)]["text"]
df2[20:40]
# Out:
# 32740    Best actor drama tv... Brody!!!!! Yeah #Golden...
# 32758    Best Actor TV Series Drama Damian Lewis for HO...
# 32761    Best Actor TV Series Drama -  Damien Lewis. #g...
# 32764    Best actor in a t. Series drama, Damien Lewis,...
# 32809    Best actor in TV series, drama #winner: Damian...
# 32824    RT @TVGuide: Best actor for TV drama goes to D...
# 32843    Best actor Tv Series/drama: Damian Lewis #Gold...
# 32914    RT @ABCNewsEnt: Damian Lewis wins best actor, ...
# 32942    Best Actor in a TV Series Drama: Damian Lewis ...
# 32956    Best actor, tv series, drama: Damien Lewis, ho...
# 32957    RT @nbc: Congrats to Damian Lewis (@lewis_dami...
# 32962    Best actor in a TV Series: Damian Lewis for Ho...
# 33003    RT @filmdotcom: Best actor in a TV series or d...
# 33010    Best Actor in TV Series-Drama: Damian Lewis. #...
# 33018    Damien Lewis wins the Globe for Best Actor TV ...
# 33029    #GoldenGlobes Damian Lewis is the new Cranston...
# ...
