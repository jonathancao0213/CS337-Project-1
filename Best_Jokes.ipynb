# %%
import numpy as np
import pandas as pd
import spacy
from spacy import displacy
from collections import defaultdict
nlp = spacy.load("en_core_web_md")

# %%
df = pd.read_json('../gg2013.json')
df = df['text']
df = df.str.replace('#GoldenGlobes|golden|globes|globe', "", case = False)
jokes_df = df[df.str.contains('funny|funniest|joke|haha|hilarious', case = False)]
print(jokes_df)
# Out:
# <ipython-input-3-7472ebae5d49>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df = df.str.replace('#GoldenGlobes|golden|globes|globe', "", case = False)
# 142            @iamsajuy I thought this was a  post.. Haha!
# 260       RT @DavidSpade: Being a guy its hard to start ...
# 329       RT @AudrinaPatridge: Loving the Mani cam on E!...
# 428       Lol RT @darrenhayes OK, so I've just seen E!'s...
# 489       RT @AudrinaPatridge: Loving the Mani cam on E!...
#                                 ...
# 174349    RT @popsugar: Aw Ben introducing the cast back...
# 174368    RT @TheEllenShow: Tina Fey and Amy Poehler are...
# 174587    RT @nbcsnl: Amy and Tina were perfection tonig...
# 174596    RT @TheEllenShow: Tina Fey and Amy Poehler are...
# 174597    Hahahahahahahahahahaha RT"@popsugar: "We're go...
# Name: text, Length: 6328, dtype: object

# %%
jokes = {}
jokes = defaultdict(lambda: 1, jokes)
for i, text in jokes_df.iteritems():
    for entity in nlp(text).ents:
        if entity.label_ == 'PERSON':
            jokes[entity.text] = jokes[entity.text] +1
            
jokes = sorted(jokes.items(), key=lambda item: item[1], reverse = True)

# %%
jokes
# Out:
# [('Amy Poehler', 1453),
#  ('Tina Fey', 1441),
#  ('Amy', 513),
#  ('Tina', 492),
#  ('Will Ferrell', 248),
#  ('Kristen Wiig', 202),
#  ('Taylor Swift', 157),
#  ('Lena Dunham', 148),
#  ('James Cameron', 130),
#  ('Jennifer Lawrence', 101),
#  ('Anne Hathaway', 96),
#  ('Tommy Lee Jones', 87),
#  ('Kristen Wiig Funny   ', 83),
#  ("Amy Poehler's", 71),
#  ('Adele', 66),
#  ('Jodie Foster', 63),
#  ('Taylor', 58),
#  ('Poehler', 56),
#  ('Sacha', 51),
#  ('Cohen', 51),
#  ('Bill Clinton', 49),
#  ('Jay Leno', 47),
#  ('George Clooney', 45),
#  ('Kristen', 44),
#  ('Meryl', 44),
#  ('Paul Rudd', 33),
#  ("Michael J. Fox's", 32),
#  ('RT', 29),
#  ('#hilarious', 28),
#  ('Meryl Streep', 27),
#  ('Will Farrell', 26),
#  ('Will Ferrel', 24),
#  ('RT @PerezHilton', 22),
#  ("Hillary Clinton's", 22),
#  ('Amy Pohler', 21),
#  ('#sofunny', 21),
#  ('Quentin Tarantino', 20),
#  ('Kristen Wigg', 19),
#  ('Russell Crowe', 19),
#  ('Amy poehler', 18),
#  ('Bradley Cooper', 18),
#  ("Jennifer Lawrence's", 18),
#  ('#Hilarious', 17),
#  ('Jessica Alba', 17),
#  ('Hahahah Will Ferrell', 17),
#  ('Wiig', 17),
#  ('Tina fey', 16),
#  ('#AmyPoehler', 16),
#  ('#toofunny', 16),
#  ('Justin Timberlake', 16),
#  ('Glenn Close', 16),
#  ('tina', 15),
#  ('Sarah Palin', 15),
#  ('Ben Affleck', 15),
#  ('Fat Alba', 15),
#  ('Kristin Wiig', 15),
#  ('Louie CK', 15),
#  ('Cheadle', 15),
#  ('#funny', 14),
#  ('Mel Gibson', 14),
#  ('Jennifer', 14),
#  ('Clinton', 14),
#  ('Chad Lowe', 14),
#  ('Beat Meryl', 14),
#  ('Daniel Day-Lewis', 13),
#  ('tina fey', 12),
#  ('Daniel Day Lewis', 12),
#  ("Taylor Swift's", 12),
#  ('Robert Downey Jr.', 12),
#  ('#heywomenarefunnytoo', 12),
#  ('Hugh Jackman', 11),
#  ('#amypoehler', 11),
#  ('Kathryn Bigelow', 11),
#  ('TinaFey', 11),
#  ('Lena', 11),
#  ('taylor swift', 11),
#  ('Nell', 11),
#  ('Amy Poehler --', 10),
#  ('Will', 10),
#  ('Kristen Wig', 10),
#  ('Arnold', 10),
#  ('Claire Danes', 10),
#  ("Michael J Fox's", 10),
#  ('Ben', 10),
#  ("Russell Crowe's", 10),
#  ('Tarantino', 9),
#  ('Tina Fey + Amy Poehler', 9),
#  ('Jessica Chastain', 9),
#  ("Hilary Clinton's", 9),
#  ('kristen wiig', 9),
#  ('JLaw', 9),
#  ('Jonah Hill', 9),
#  ('Aziz Ansari', 9),
#  ('Aziz', 9),
#  ('#MyGirl', 9),
#  ('#loveit', 8),
#  ("Tina Fey's", 8),
#  ('Ricky Gervais', 8),
#  ('Fey', 8),
#  ('amy poehler', 8),
#  ('ahahaha adele', 8),
#  ('cunt', 8),
#  ('Kristin', 8),
#  ('Ferrel', 8),
#  ('Kristen wiig', 8),
#  ('Lea Michele', 8),
#  ('Jodi Foster', 8),
#  ('James Franco', 7),
#  ('TINA FEY', 7),
#  ('Maggie Smith', 7),
#  ('#lol', 7),
#  ('Eva Longoria', 7),
#  ("Mel Gibson's", 7),
#  ('#adele', 7),
#  ('tommy lee jones', 7),
#  ('Harvey', 7),
#  ('Harvey Weinstein', 7),
#  ("James Cameron '", 7),
#  ('Helen Hunt', 7),
#  ('Stallone', 7),
#  ('Lea', 7),
#  ('Jimmy Fallon', 7),
#  ('Jodie', 7),
#  ("Jessica Chastain's", 6),
#  ('Lol', 6),
#  ('Hathaway', 6),
#  ('Tina Fay', 6),
#  ('GetGlue', 6),
#  ('Palin', 6),
#  ('Carrie', 6),
#  ("Will Ferrell's", 6),
#  ('Megan Fox', 6),
#  ('Arnold Schwarzenegger', 6),
#  ('Tan Mom', 6),
#  ('Jason Bateman', 6),
#  ('Clooney', 6),
#  ("George Clooney's", 6),
#  ('#bestever', 6),
#  ("Jodie Foster's", 6),
#  ('Leno', 6),
#  ('Sofia Vergara', 5),
#  ('amy', 5),
#  ('Cameron', 5),
#  ('Anne', 5),
#  ('#tinaandamy', 5),
#  ('Omg', 5),
#  ('Christoph Waltz', 5),
#  ('Richard Gere', 5),
#  ('Julianne Moore', 5),
#  ('Tina Fey LOL', 5),
#  ('Damian Lewis', 5),
#  ('Jennifer Lopez', 5),
#  ('Kevin Costner', 5),
#  ('bill Clinton', 5),
#  ("HILLARY CLINTON'S", 5),
#  ('Tommy Lee', 5),
#  ('JENNIFER LAWRENCE', 5),
#  ('Rob', 5),
#  ('RT @CELEBUZZ', 5),
#  ('Jen', 5),
#  ("Anne Hathaway's", 5),
#  ('Jennifer Garner', 5),
#  ('Don Cheadle', 5),
#  ('Schwarzenegger', 5),
#  ('Sylvester Stallone', 5),
#  ('Sasha', 5),
#  ('Margareth Menezes', 5),
#  ('#Girls', 5),
#  ('J.Lo', 5),
#  ('#JodieFoster', 5),
#  ('#HAHAJK', 5),
#  ('Victor Garber', 5),
#  ('Amy P', 4),
#  ('Al Roker', 4),
#  ('Jay', 4),
#  ('#tinafey', 4),
#  ("Bill Murray's", 4),
#  ('Bill', 4),
#  ('Bigelow', 4),
#  ('#FunnyGals', 4),
#  ('Oscar', 4),
#  ('OMG Tina Fey', 4),
#  ('Amy Poheler', 4),
#  ('Quentin', 4),
#  ('#SNL', 4),
#  ('Amy Poeler', 4),
#  ('#AmyPohler', 4),
#  ('Mitt Romney', 4),
#  ('@lenadunham', 4),
#  ('Batman', 4),
#  ('Aida Takla', 4),
#  ('Robert Downey Jr', 4),
#  ('J Lo', 4),
#  ('#loveher', 4),
#  ('@PerezHilton', 4),
#  ('Bill Rodham Clinton', 4),
#  ('Tay', 4),
#  ('Kirsten Wiig', 4),
#  ('#willferrell', 4),
#  ('La', 4),
#  ('#notfunny', 4),
#  ('Farrell', 4),
#  ('Les Mis', 4),
#  ('Lawrence', 4),
#  ('#JenniferLawrence', 4),
#  ('Oscars', 4),
#  ('Sylvester', 4),
#  ('Arnie', 4),
#  ('Haneke', 4),
#  ('AMY', 4),
#  ('Michael Haneke', 4),
#  ('#gg', 4),
#  ('#girls', 4),
#  ('george clooney', 4),
#  ('TAYLOR SWIFT', 4),
#  ('Foster', 4),
#  ('Affleck', 4),
#  ('Hillary Swank', 4),
#  ('Dustin', 4),
#  ('Dustin Hoffman', 4),
#  ('Lewis', 4),
#  ('#argo', 4),
#  ("mani cam'", 3),
#  ('Julianna Margulies re', 3),
#  ('#poehler', 3),
#  ('Ricky', 3),
#  ('Will Arnett', 3),
#  ('Bill Murray', 3),
#  ('james cameron', 3),
#  ('OMG AMY', 3),
#  ('#SoFunny', 3),
#  ('Fay', 3),
#  ('#zing', 3),
#  ('http://t.co/50DeLhr7', 3),
#  ('Joaquin Phoenix', 3),
#  ('Russell Crowe stoneface', 3),
#  ('Franco', 3),
#  ('Amy Polar', 3),
#  ('Tina Faye', 3),
#  ('Tina Feye', 3),
#  ('Amy Phoeler', 3),
#  ('#bestjokeofthenight', 3),
#  ('#funnywomen', 3),
#  ('Meryl Streep/Flu', 3),
#  ("Ben Affleck's", 3),
#  ('Loving Amy', 3),
#  ('Dennis Quaid', 3),
#  ('#funnyladies', 3),
#  ('#Amy&amp;Tina', 3),
#  ('@DaDishE', 3),
#  ('Haha Amy Poehler', 3),
#  ('Catherine Zeta Jones', 3),
#  ('Catherine Zeta-Jones', 3),
#  ('#justsaying', 3),
#  ('Robin', 3),
#  ('Cdlm', 3),
#  ('#hahahah', 3),
#  ('Jon Hamm', 3),
#  ('Susan Lucci', 3),
#  ('Salma Hayek', 3),
#  ('#HILARIOUS', 3),
#  ('#Bert', 3),
#  ('doodyfart', 3),
#  ('Brody', 3),
#  ('paul rudd', 3),
#  ('#bluecarpet', 3),
#  ('John Goodman', 3),
#  ('Jason Statham', 3),
#  ('Daniel Craig', 3),
#  ('Christina Aguilera', 3),
#  ('XD', 3),
#  ('Nene', 3),
#  ('#keepingitreal', 3),
#  ('TAYLOR', 3),
#  ('Dick', 3),
#  ('Michael Haneke ha', 3),
#  ('Benedict Cumberbatch', 3),
#  ('Benedict', 3),
#  ('ellen', 3),
#  ('Hillary', 3),
#  ('BILL RODHAM CLINTON', 3),
#  ('LMAO Tina Fey', 3),
#  ('#YouGetOutOfHere', 3),
#  ('Kristin wiig', 3),
#  ('Omg funnyRT', 3),
#  ('Will Ferell', 3),
#  ('Jack Black', 3),
#  ('Kristin Wigg', 3),
#  ('Osama bin Laden', 3),
#  ('Tommy', 3),
#  ('Kristin wigg', 3),
#  ('Chris Tucker', 3),
#  ('#WillFerrell', 3),
#  ('Jennifer lawrence', 3),
#  ('Jennifer Lawerence', 3),
#  ('jennifer lawrence', 3),
#  ('Lincoln', 3),
#  ('Will ferrell', 3),
#  ('#cdnpoli', 3),
#  ('#sofunny #lovethem', 3),
#  ('#tommyleejones', 3),
#  ('meryl', 3),
#  ('#SuryaRay', 3),
#  ('#Surya', 3),
#  ('Jamie Fox', 3),
#  ('Fantine', 3),
#  ('#catchafallingstarandputitinyourpocket', 3),
#  ('Sweet', 3),
#  ('Esp w', 3),
#  ("Tommy Lee Jones'", 3),
#  ('Mufasa', 3),
#  ('Jeremy Irons', 3),
#  ('Lucy Liu', 3),
#  ('Amy Poehler Hilarious Opening', 3),
#  ('Hahha Will Ferrell', 3),
#  ('Jim Parsons', 3),
#  ('Gordon', 3),
#  ('Glen Close', 3),
#  ('Lea Michelle', 3),
#  ("Mark Wahlberg's", 3),
#  ('Lisa Dunham', 3),
#  ('Margareth Menezes melhor', 3),
#  ('#nojoke', 3),
#  ('LOL', 3),
#  ('OMG Glenn Close', 3),
#  ('Amy Poehlrs Hilarious', 3),
#  ('TINA FAY', 3),
#  ('Spielberg', 3),
#  ('#LesMiserables', 3),
#  ('jodie foster', 3),
#  ("jodie foster's", 3),
#  ('mel gibson', 3),
#  ('Jodie Fosters', 3),
#  ('Paul Thomas Anderson', 3),
#  ('Orson Welles', 3),
#  ('Funny', 3),
#  ('Jimmy', 3),
#  ('CHAD LOWE', 3),
#  ('Hilary Swank', 3),
#  ('#GIRLS', 3),
#  ('dick', 3),
#  ("Justin Bieber's", 3),
#  ("Dustin Hoffman's", 3),
#  ('Tim Whatley', 3),
#  ('#salivaisfunny', 3),
#  ('#HoroscopoNocturno', 3),
#  ('Lol RT', 2),
#  ('RT @deepa_k', 2),
#  ('Amy/Tina', 2),
#  ('LOLOLOLOLOLOL Giuliana', 2),
#  ('Denzel aime les formes', 2),
#  ('Kanina pako', 2),
#  ('Xcited', 2),
#  ('Miranda Kerr', 2),
#  ('Lila Morillo en los', 2),
#  ('Buahaha', 2),
#  ('#NBCRedcarpet', 2),
#  ('Sally Field', 2),
#  ('Matt Lauer', 2),
#  ('JAY LENO', 2),
#  ('Will Tina Fey', 2),
#  ('#GameofThrones', 2),
#  ('TMZ', 2),
#  ('#TheHeat', 2),
#  ('#amyandtinarock', 2),
#  ('#divalishdesigns Amy Poehler -- Parks', 2),
#  ("Loving Amy Poehler's", 2),
#  ('#cantwait', 2),
#  ('- Amy Poehler', 2),
#  ('nw   ', 2),
#  ('tina faye', 2),
#  ('Robert Downey', 2),
#  ('JAMES CAMERON', 2),
#  ('Que hija de puta', 2),
#  ('jessica chastain', 2),
#  ('Hahahahahahahaa OMG Amy', 2),
#  ('Jc', 2),
#  ('DAMN AMY', 2),
#  ('James Cameron Jokes', 2),
#  ('#ackwardlaugh', 2),
#  ('CAMERON', 2),
#  ('apresentadora', 2),
#  ('#JamesCameron #zerodarkthirty', 2),
#  ('Props', 2),
#  ('#amypoelher', 2),
#  ('#camerontorturejoke', 2),
#  ('LOL james cam', 2),
#  ("OMG Jessica Chastain's", 2),
#  ('Ouch', 2),
#  ('James Cameon', 2),
#  ('james camron', 2),
#  ('Love Amy', 2),
#  ('#gorgeous', 2),
#  ('nem sei o', 2),
#  ('sto morendo', 2),
#  ("AHAHAHAHA Joaquin's", 2),
#  ('BFF', 2),
#  ('jim cameron', 2),
#  ('Corona', 2),
#  ('#killingitwiththesejokes', 2),
#  ('Franko', 2),
#  ('Kathryn Bigalow', 2),
#  ('AMY POEHLER', 2),
#  ('#dyingrightnow', 2),
#  ('Lol Amy Phoelber', 2),
#  ('Ben Affleck Boston', 2),
#  ('omg tina', 2),
#  ('tan pesadas las bromas', 2),
#  ('jajaja', 2),
#  ('#badumtss', 2),
#  ('amy pohler', 2),
#  ('#noneofushaveplanstodoporn', 2),
#  ('#LesMis', 2),
#  ('Amy Poelher est en feu', 2),
#  ('Anne Hatheway', 2),
#  ('#dead', 2),
#  ('Anne Hathaway-James Franco', 2),
#  ('Omg Tina Fey', 2),
#  ('#myheroes', 2),
#  ('Tina Fey y Amy Poehler', 2),
#  ("GIF Jessica Chastain's", 2),
#  ('#fey', 2),
#  ('#tofunny', 2),
#  ('haha Meryl Streep', 2),
#  ('#tooFunny', 2),
#  ('Ahh Tina Fey', 2),
#  ('SARAH PALIN', 2),
#  ('Amy Poehier', 2),
#  ('#amen', 2),
#  ('Detrás de todos los', 2),
#  ('HAHAHAHAHAHAAHA É', 2),
#  ('jack', 2),
#  ('RT @KathyBenjamin', 2),
#  ('#perfectduo', 2),
#  ('👏', 2),
#  ('Amy Poehler r killin', 2),
#  ('RT @benfinzel', 2),
#  ('womenrulecomedy', 2),
#  ('Amy Poehlers', 2),
#  ('Tina y Amy', 2),
#  ('E.T.', 2),
#  ('Mandy Patinkin', 2),
#  ('#bestopening', 2),
#  ('LMFAO', 2),
#  ('Tina/Amy', 2),
#  ('Pi', 2),
#  ('Amy Peohler', 2),
#  ('Lmfao Tina Fey', 2),
#  ('Ainda estou emocionada com', 2),
#  ('Leonardo DiCaprio', 2),
#  ('Schnitt', 2),
#  ('Legit', 2),
#  ('#WhoKnew', 2),
#  ('Damn @', 2),
#  ('#wayfunny', 2),
#  ('#sorrynotsorry Muahahaha', 2),
#  ('#perfecthosts', 2),
#  ('Friggin', 2),
#  ('Any Poehler', 2),
#  ('#gga', 2),
#  ('Amy poller', 2),
#  ('😆', 2),
#  ('#TinaFey', 2),
#  ('Joan Rivers', 2),
#  ('#christoph', 2),
#  ('#funnygirls', 2),
#  ('Dame Maggie Smith', 2),
#  ('Philip Seymour Hoffman', 2),
#  ('countess', 2),
#  ('#hackjoke', 2),
#  ('OMFG Tina Fey', 2),
#  ('Ryan"', 2),
#  ('Gryffindor', 2),
#  ("Kate Hudson's", 2),
#  ('Bahaha Maggie Smith', 2),
#  ('No Maggie Smith', 2),
#  ('No Meryl Streep', 2),
#  ('Countess', 2),
#  ('#jokes overerrythang', 2),
#  ('#TeamFeyPoehler #', 2),
#  ('Bravo Tina', 2),
#  ('Amy Hilarious', 2),
#  ('Amy Poelher', 2),
#  ('Yay Maggie Smith', 2),
#  ('Bruce Vilanch', 2),
#  ('Tine', 2),
#  ('Meg Ryan', 2),
#  ('Amy Poehlr', 2),
#  ('@pepsi', 2),
#  ('#honeybooboo', 2),
#  ('#ducktales', 2),
#  ('#funnyshit', 2),
#  ("Sofia Vergara's", 2),
#  ('#nailedit', 2),
#  ('tyra fucked', 2),
#  ('#FNL', 2),
#  ('RT @mamaspohr', 2),
#  ('Richard Parker', 2),
#  ("t'oblige à te mettre", 2),
#  ('fais nous signe', 2),
#  ("Je m'en remets pas", 2),
#  ('Michael J. Fox', 2),
#  ('natalie portman', 2),
#  ('RT @KaJo503', 2),
#  ('Sarah palin', 2),
#  ('LOLLLLL Amy', 2),
#  ('Amy aint ish', 2),
#  ('Ja ja a botam', 2),
#  ('Amu', 2),
#  ('Jajaja', 2),
#  ('Parks', 2),
#  ('Recreation', 2),
#  ('Amy Poelher en Julianne Moore', 2),
#  ('Julianne Moore’s', 2),
#  ('GameChange', 2),
#  ('Juliane Moore dando recadinho', 2),
#  ('Darcy St. Fudge.', 2),
#  ('Jessica Lange', 2),
#  ('Amy Poehler Moore', 2),
#  ('Omg amy', 2),
#  ('Loving Amy Poehler', 2),
#  ('DAN Hathaway', 2),
#  ('30Rock', 2),
#  ('eu querendo saber', 2),
#  ('gerúndio', 2),
#  ('her?', 2),
#  ('Catherine ZJ', 2),
#  ('#LeaveItToTheComics', 2),
#  ('ctown', 2),
#  ('#haha', 2),
#  ('#iseeyou', 2),
#  ('u 4', 2),
#  ('haaay', 2),
#  ('Bahahah', 2),
#  ('#hollywoodsucks', 2),
#  ('Meu sonho sempre foi ver', 2),
#  ('Britney', 2),
#  ('Adam Carolla', 2),
#  ('#humour', 2),
#  ('Omg @ZooeyDeschanel', 2),
#  ('ganó Julianne Moore', 2),
#  ('así o más felices', 2),
#  ('Amy Pohlers', 2),
#  ('Meu pai recalcado que vai ter que trabalhar enquanto', 2),
#  ('passa os', 2),
#  ('Hahahhahaa eu adoravaaa', 2),
#  ('Hahahaha otra vez hablando de #THG en los .', 2),
#  ('Amy Poler', 2),
#  ('chick', 2),
#  ("hoooo foreign lady's", 2),
#  ('ryan', 2),
#  ('Para comentários', 2),
#  ('JEFFREY KATZENBERG', 2),
#  ('#callmemaybe', 2),
#  ('Jesus', 2),
#  ('Pres', 2),
#  ('#jeffreykatzenberg', 2),
#  ('#bradleycooper', 2),
#  ('#KillerIntro', 2),
#  ('Até eu que sou mais boba falaria para o Bradley Cooper', 2),
#  ('Bradley Cooper&gt;&gt;&gt', 2),
#  ('da presidenta pra bradley cooper', 2),
#  ('hahahaha Paul Rudd', 2),
#  ('Salma Hayes', 2),
#  ('Denny', 2),
#  ('Tina n Amy', 2),
#  ('RUDD 4EVA', 2),
#  ('- Dev Patel', 2),
#  ('RT @dawnie78', 2),
#  ('ACERTEI O LEWIS', 2),
#  ('Ishocker', 2),
#  ('#homeland', 2),
#  ("Paul Rudd's", 2),
#  ("Kathryn BIgalow's", 2),
#  ('RT @piersmorgan', 2),
#  ('Selma Hayek', 2),
#  ('Ela falou Twilight', 2),
#  ('da @TNTbr', 2),
#  ('wtf', 2),
#  ('Que pena', 2),
#  ('#telepromtershitthebed', 2),
#  ('#epicfail', 2),
#  ('Pas de télésouffleur', 2),
#  ('#veep', 2),
#  ('pres', 2),
#  ('doido hoje hein', 2),
#  ('Rudd-Hayek', 2),
#  ('#livetv', 2),
#  ('#paulrudd', 2),
#  ('ganhou melhor série de drama', 2),
#  ('RT @TheJillKushner', 2),
#  ('lol  ', 2),
#  ('Damian', 2),
#  ('Amy - Great', 2),
#  ('James C', 2),
#  ('LOL RDJ', 2),
#  ('#funnywomendoexist', 2),
#  ('Robert Downey Jr. e Mel Gibson na mesma mesa', 2),
#  ('God', 2),
#  ('White', 2),
#  ('PELA ELE CARRIE', 2),
#  ('HAUAHAHAUAH', 2),
#  ('RT @1brunoporto', 2),
#  ('Hahaha Robert Downey Jr.', 2),
#  ('#howcute', 2),
#  ('sou foda e cheguei', 2),
#  ('ko lang', 2),
#  ('yung blog sa', 2),
#  ('lang ako ng mga dress', 2),
#  ('hahaha paul rudd', 2),
#  ('amy pholer', 2),
#  ('AIG', 2),
#  ('excelente serie', 2),
#  ('Paul', 2),
#  ('boba NADA', 2),
#  ('#Salma', 2),
#  ('RT @sbrownehr RT', 2),
#  ('#JulianneMoore', 2),
#  ('Robert Downey Jr. beijando o rosto', 2),
#  ("Bradley Cooper's", 2),
#  ('Pura verdade', 2),
#  ('teringan Nya nak jalan kat Red Carpet', 2),
#  ('Jason Stratham', 2),
#  ('Watch Argo', 2),
#  ('Tina Fey&amp;Amy Poehler', 2),
#  ('Carga Explosiva', 2),
#  ('BWAHAHAHA RT @erniebufflo', 2),
#  ('Bwahahaha RT', 2),
#  ('JLo', 2),
#  ('Michaels', 2),
#  ('#AllHorrorAllTheTime', 2),
#  ('haha yoshiki', 2),
#  ('Omg RT @JenniferUpdates', 2),
#  ('#twitter', 2),
#  ('#KathrynBigelow', 2),
#  ('Les Miserablah', 2),
#  ('twitter', 2),
#  ('Ninang Adele', 2),
#  ('#Adele', 2),
#  ('HAHAHAH CTM RT @WalterTapia', 2),
#  ('@MumfordAndSons', 2),
#  ('Adele es demasiado comica', 2),
#  ('Vontade de apertar', 2),
#  ("TAYLOR SWIFT'S", 2),
#  ('AHAHAH ADEL', 2),
#  ('Josh', 2),
#  ('HAHAHAH CTM RT', 2),
#  ('RHOA', 2),
#  ('Greg', 2),
#  ("taylor swift's", 2),
#  ('diet pepsi reklamı çıktı', 2),
#  ('@jbranca92', 2),
#  ("Aww Adele's", 2),
#  ('#madfunny', 2),
#  ('Love Adele', 2),
#  ('#eredcarpet', 2),
#  ('http://t.co/Dg8WSbp2', 2),
#  ('Yay @Adele', 2),
#  ('Duda existencial cada', 2),
#  ('RT @djjcnavarro', 2),
#  ('La cara De envidia de la puta de Taylor Swift', 2),
#  ('Adele es la mejor', 2),
#  ('cara de recalque', 2),
#  ("Leonardo DiCaprio's", 2),
#  ('Leslie Knope', 2),
#  ('Amy Poehler Open', 2),
#  ('#tinafeyamypoehler', 2),
#  ('RT"@Cosmopolitan', 2),
#  ('bahaha bc', 2),
#  ('Goodman', 2),
#  ('#makeithappen', 2),
#  ('Aww Adele', 2),
#  ('#SorryNotSorry  ', 2),
#  ('#loveyou', 2),
#  ('#hahahakidding', 2),
#  ('Grinch', 2),
#  ('LOL Adele', 2),
#  ('Dave', 2),
#  ('Rosanne', 2),
#  ('James', 2),
#  ('#pissingmyselfatyourspeech', 2),
#  ('quanto ho capito tutti', 2),
#  ('ma gaawd', 2),
#  ('Hahahahah Tina', 2),
#  ('hahahah taylor swift', 2),
#  ('Downton', 2),
#  ('hahahahahahhahahahaha', 2),
#  ("Jennifer Lopez's", 2),
#  ('cumberbatch', 2),
#  ('Hahahaha wtf Tina Fey', 2),
#  ('Damien Francisco', 2),
#  ('RT @GangstaTrippin', 2),
#  ('#WheresTina', 2),
#  ('WheresWaldo', 2),
#  ('Cumberbatch', 2),
#  ('zerou o', 2),
#  ('HAHAHAHAHAHAHAHAHAHA KEVIN COSTNER WON AN', 2),
#  ('Johnny Depp', 2),
#  ('Any Polher', 2),
#  ("Amy Poeler's", 2),
#  ('wtf omfg hahahaha billy', 2),
#  ('it`s', 2),
#  ('haha esto si da risa', 2),
#  ('Wtf', 2),
#  ('#explanationplease', 2),
#  ('Davies', 2),
#  ('Jen que já ganhou', 2),
#  ('Monica', 2),
#  ('LENA DUNHAM', 2),
#  ('#billclinton', 2),
#  ('CLINTON', 2),
#  ('Ahahahahahahahahaha hahahha WTF', 2),
#  ('RobertDowneyJr', 2),
#  ('Obama', 2),
#  ('LOL Lena Dunham’s', 2),
#  ('bill clinton en', 2),
#  ('Adele WHAHAHAHAHAHA', 2),
#  ('William Jefferson Clinton', 2),
#  ('#bestpresident', 2),
#  ('Bush', 2),
#  ('y el viejo Bill', 2),
#  ('Hahaha Amy Poehler', 2),
#  ('#ILU', 2),
#  ('#freakinfunny', 2),
#  ('Hahahahaha Amy', 2),
#  ('@katiecouric Amy Poehler', 2),
#  ('pareció ver al Joker', 2),
#  ('Anjelica Houston', 2),
#  ('#  ', 2),
#  ('Bill Rodham', 2),
#  ('Kristen Wiigs "Taylor', 2),
#  ('Haha Taylor Swift', 2),
#  ('RT @ALiberalLady', 2),
#  ('Will Farrell tag', 2),
#  ('Kristen Wiig - Wow', 2),
#  ("Will Farrell's", 2),
#  ('Langya', 2),
#  ('A. Houston', 2),
#  ('Hahahaha Bill "Rodham', 2),
#  ('#hilarious RT', 2),
#  ('#bestlineofthenight', 2),
#  ('omfg Will', 2),
#  ('Wil Ferrell', 2),
#  ('Jimmy Carter', 2),
#  ('lol  will ferrell', 2),
#  ('Will Ferrall', 2),
#  ('Hahahahahahha Kristin', 2),
#  ('HAHAHAHAHAHHAHAHAHAHA Quem ta vendo', 2),
#  ('Ta mto engracado', 2),
#  ('m dyinggggggg   ', 2),
#  ('Will Farell', 2),
#  ('#GG', 2),
#  ('#overboardjokes', 2),
#  ('Love Kirsten', 2),
#  ('Haha J La!', 2),
#  ('Hahahah Kristen Wiig', 2),
#  ('Will Ferrell y Kristen', 2),
#  ('Damn', 2),
#  ('#kristinwiig', 2),
#  ('Bahaha', 2),
#  ('ali na platéia é', 2),
#  ('Anjelica Huston', 2),
#  ('youuuuu gett ouuuttt"', 2),
#  ('Bahahaha Kristen Wiig', 2),
#  ('#snlduo', 2),
#  ('OMG Tommy Lee Jones', 2),
#  ('Y miren quien lo dice', 2),
#  ('Kristin Wig', 2),
#  ('sakit ng panga ko Hahahaahahahha', 2),
#  ('gloden', 2),
#  ('#JLAW', 2),
#  ('#kristenwiigislife', 2),
#  ('Kristin Wiig - awesome', 2),
#  ("Hahahah Tommy Lee Jones'", 2),
#  ("Tommy Lee's", 2),
#  ('Tommy lee', 2),
#  ('Kristen Wiig &amp', 2),
#  ('#Omg Will Ferrell', 2),
#  ('ahahaahahahhah tommy lee jones', 2),
#  ('trattieni le risate Lord', 2),
#  ('Jlaw', 2),
#  ('Tommy Jones', 2),
#  ('#SNL Kristen', 2),
#  ('#Comedy', 2),
#  ('RT @deecarvalho15', 2),
#  ('Ahh Will', 2),
#  ("Will Farrel's", 2),
#  ('#dudeyouregettingadell', 2),
#  ('Tom Jones', 2),
#  ('es un genio', 2),
#  ('Gülmekten karnım ağrıdı artık salaklar ahahah', 2),
#  ('KW', 2),
#  ('Wiig/Ferrell', 2),
#  ('#Swifties', 2),
#  ('#FacialExpressions', 2),
#  ('HAHAHAHAHA Tommy Lee Jones', 2),
#  ('Hahahah RT @amwithenshaw', 2),
#  ('RT @CHFIErin', 2),
#  ('Gilly', 2),
#  ('Ferrell', 2),
#  ('Jennifer Lawrence Hahahaha', 2),
#  ('Emily Blunt', 2),
#  ('MERYL STREEP', 2),
#  ('#RUDE', 2),
#  ('#yougetoutofhere', 2),
#  ('Whig', 2),
#  ('#Genius', 2),
#  ('Jennifer Lawrence @', 2),
#  ('#sodamnfunny', 2),
#  ('#whoknew', 2),
#  ('Judy Dench', 2),
#  ('#watchitboo', 2),
#  ('Katniss Everdeen', 2),
#  ('J\'ai battu Meryl" toi', 2),
#  ('morte', 2),
#  ('Wow Jennifer Lawrence', 2),
#  ('#jenniferlawrence', 2),
#  ("Tommy Lee Jones's", 2),
#  ('#wordsofthegrandfather', 2),
#  ('#sofrickenhilarious', 2),
#  ('meryl streep', 2),
#  ('altın küreyi o kadar sömürdü ki bu seferde alsaydı kan çıkardı', 2),
#  ('RT @NerdyWonka', 2),
#  ('George W Bush', 2),
#  ('@katiecouric Jennifer Lawrence "', 2),
#  ('jennifer lawrence..', 2),
#  ('#swoon', 2),
#  ('Hahahaha laftrip', 2),
#  ('J.La', 2),
#  ("Love Jennifer Lawrence's", 2),
#  ('Weinstein', 2),
#  ('Makala Maroney', 2),
#  ('Harvey W.', 2),
#  ('Hahaha Jennifer Lawrence', 2),
#  ('Katherine Weigel', 2),
#  ('tina fey+amy Poehler', 2),
#  ('Christina Hendricks', 2),
#  ('#snl', 2),
#  ('Mariah Carey', 2),
#  ('J-Lo', 2),
#  ('Mariah', 2),
#  ('ButStop', 2),
#  ('J. La', 2),
#  ('que debochada', 2),
#  ('#yougetouttahere', 2),
#  ('Kristen Wiig&gt;&gt;&gt;&gt', 2),
#  ('#Sofunny', 2),
#  ('Judi Dench', 2),
#  ('Meryl wah waah', 2),
#  ('Jennifer Lawrence - beautiful', 2),
#  ('Tom Selleck', 2),
#  ("Meryl Streep's", 2),
#  ('RT @StevePopper', 2),
#  ('Aaron Sele', 2),
#  ('Kristen Wigg - hilariousssssss', 2),
#  ('eva', 2),
#  ('Tommie Lee Jones', 2),
#  ('RT @maysoonzayid', 2),
#  ('Willy', 2),
#  ('Adele beat Taylor', 2),
#  ('Bahaha XD Kristen Wiig', 2),
#  ('#MerylStreep', 2),
#  ('#stoletheshow', 2),
#  ('Jenifer Lawrence', 2),
#  ('Ferrell-', 2),
#  ("James Cameron's", 2),
#  ('@suryaray @suryaray', 2),
#  ('JEN LAWRENCE', 2),
#  ('EMILY DESCHANEL❤', 2),
#  ('Kristen Wiig y', 2),
#  ("Jennifer Lawrence - her '", 2),
#  ('#JenniferLawerence', 2),
#  ('#didntevencrackasmile', 2),
#  ('J. Lawrence', 2),
#  ('Sheesh Jennifer Lawrence', 2),
#  ('eu nem sabia que o', 2),
#  ('Jen Laurence', 2),
#  ('#kristenwiig', 2),
#  ('#LOL', 2),
#  ('o cara de Homeland', 2),
#  ('#Awani', 2),
#  ('Merryl', 2),
#  ('Wild Camel', 2),
#  ('#newgirl', 2),
#  ('Max', 2),
#  ('#JLaw', 2),
#  ('#justjokespeople', 2),
#  ('Ferrell n Wiig', 2),
#  ('ricky bobby', 2),
#  ('latar RT', 2),
#  ('#JonahHill', 2),
#  ('Hahah RT', 2),
#  ('Mario Anzuoni', 2),
#  ("#AmyPoehler's", 2),
#  ('#tarantino', 2),
#  ('#cinemitgg', 2),
#  ('#lindsaylohan', 2),
#  ('#youreirrelevant', 2),
#  ('#Shazam', 2),
#  ('Hahahanot', 2),
#  ('MeganFox se', 2),
#  ('Max Greenfield', 2),
#  ('Schmidt', 2),
#  ('porem ela acabou de sair', 2),
#  ('linda da Anne ganhou o Globo de Ouro', 2),
#  ('Anne Hathaway gano el  y', 2),
#  ('Megan FOX', 2),
#  ('Genovia', 2),
#  ('Anne Hath', 2),
#  ('#django', 2),
#  ('Gusto ko talaga', 2),
#  ('mapanood yung', 2),
#  ('Unchained ni Jamie Foxx', 2),
#  ('#dreamgirls', 2),
#  ('#proudafricanamerican', 2),
#  ('Blerg', 2),
#  ('Djenga', 2),
#  ('Mrs Veep', 2),
#  ('Yay Anne Hathaway', 2),
#  ('RT @enochncube', 2),
#  ('Marido da Anne é feio e velho', 2),
#  ('Como eu sou chata', 2),
#  ('Sally Fields', 2),
#  ('#LoveAdele', 2),
#  ('eredcarpet', 2),
#  ('oscar', 2),
#  ('Theodora', 2),
#  ('#ibeatmeryl', 2),
#  ('RT @janetdirks', 2),
#  ('Kristen Whig', 2),
#  ('#justsayin', 2),
#  ('Anne Hathaways', 2),
#  ('picasso Ryan Gosling', 2),
#  ('This Sofia Vergara Diet Pepsi', 2),
#  ('ver os   ', 2),
#  ('http://t.co/WMstUrO9', 2),
#  ("Rob Pattinson's", 2),
#  ('Hahahaha que Sally Field y Helen Hunt eran las favoritas', 2),
#  ('Puh-leeeease', 2),
#  ('Pelaron cono', 2),
#  ('J Lawr', 2),
#  ('Helena Bonham Carter', 2),
#  ('#', 2),
#  ('Jennifer Lawrnce', 2),
#  ('Eva', 2),
#  ('Amanda', 2),
#  ('Amanda e Rob', 2),
#  ('Ta ai um', 2),
#  ('AMANDA', 2),
#  ('Robert Pattinson', 2),
#  ('@britneeng Haha', 2),
#  ('Tuh @DimustCOD', 2),
#  ('bukan artis', 2),
#  ('sok ngartis', 2),
#  ('siapa artis', 2),
#  ('yang paling cetar menurut Lazadian', 2),
#  ('Não sei se', 2),
#  ('Robert tá', 2),
#  ('Amanda Seyfried sempre', 2),
#  ('rt @J_Fernz', 2),
#  ('James Bond', 2),
#  ('Es un excelente', 2),
#  ('y guionista', 2),
#  ('Josh n Lauren', 2),
#  ("Paul Rudd nos TT's", 2),
#  ('Acabei de falar como o adoro', 2),
#  ('RT @leslieheimer', 2),
#  ('kra o', 2),
#  ('Wayment', 2),
#  ('Samuel L Jackson', 2),
#  ('Spike Lee', 2),
#  ('HAHA Salmons time', 2),
#  ('#funny RT', 2),
#  ('ahah aha h', 2),
#  ('Deb Messing', 2),
#  ('Mufaaaasa', 2),
#  ('Scar', 2),
#  ('#NeverForget', 2),
#  ('Don', 2),
#  ('Hahaja Louis C.K.', 2),
#  ('Joey', 2),
#  ('http://t.co/rrYENebK via', 2),
#  ('#Adele&gt', 2),
#  ('Lucy Liu ta vestindo', 2),
#  ('Jamaal Al-Din - NBA', 2),
#  ('#marrymetina', 2),
#  ('#DonCheadle', 2),
#  ('#bigbangtheory', 2),
#  ('hunter på', 2),
#  ('Obligatorisk', 2),
#  ('Debra', 2),
#  ('Madame', 2),
#  ('pulak banyak retweets psl   award', 2),
#  ('Tapi', 2),
#  ('Gervais', 2),
#  ('#glibes', 2),
#  ('Lindsay Lohan', 2),
#  ('Anne hathaway', 2),
#  ('#girlcrush', 2),
#  ('Arnold Schwazsafnahgj', 2),
#  ...]

# %%
best_jokes_person = jokes[0][0]
print("Best Dressed: " + best_dressed_person)
