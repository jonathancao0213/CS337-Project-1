# %%
import numpy as np
import pandas as pd
import spacy
from spacy import displacy
from collections import defaultdict

# %%
nlp = spacy.load("en_core_web_md")

# %%
df = pd.read_json('../gg2013.json')
df = df['text']
df = df.str.replace('#GoldenGlobes|golden|globes|globe', "", case = False)
dressed_df = df[df.str.contains('best dressed|glamorous|jealous|dress|stunning|fav|gorgeous', case = False)]
print(dressed_df)
# Out:
# <ipython-input-19-24b2e80d3af0>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df = df.str.replace('#GoldenGlobes|golden|globes|globe', "", case = False)
# 0                                 JLo's dress! #eredcarpet
# 4                   Jennifer Lopez's lace dress? Thoughts?
# 11        Jennifer Lopez's dress is jaw droppingly amazi...
# 13            Werk @kerrywashington Stunning!!!  red carpet
# 19        RT @AudrinaPatridge: @SofiaVergara is my favor...
#                                 ...
# 174540    2013   Makeup, Hair, Dresses Recap: Claire Dan...
# 174545    I'm not all into red carpet fashion, but Miche...
# 174598    RT @RPLife: 2 Red Carpet HQs added and maybe m...
# 174603    My fave dresses at   👗 #fashion #amyadams #meg...
# 174610      2013 Worst-Dressed List: See The Fashion Flo...
# Name: text, Length: 6936, dtype: object

# %%
# lana_tweets = df[df.str.contains('lana del rey', case = False)]
# lana_tweets = lana_tweets[~lana_tweets.str.contains('worst|bad|ugly|hate', case = False)]

# lana_tweets

# %%
if dressed_df.shape[0] > 8000:
    dressed_df = dressed_df.sample(n=8000)

# %%
dressed = {}
dressed = defaultdict(lambda: 1, dressed)
for i, value in dressed_df.iteritems():
    for entity in nlp(value).ents:
        if entity.label_ == 'PERSON':
            dressed[entity.text] = dressed[entity.text] +1
            
dressed = sorted(dressed.items(), key=lambda item: item[1], reverse = True)

# %%
best_dressed_person = dressed[0][0]
print("Best Dressed: " + best_dressed_person)
# Out:
# Best Dressed: Kate Hudson

# %%
#took ~25 minutes
dressed
# Out:
# [('Kate Hudson', 195),
#  ('Anne Hathaway', 162),
#  ('Jessica Alba', 151),
#  ('Jennifer Lawrence', 147),
#  ('Tina Fey', 114),
#  ("Kate Hudson's", 113),
#  ("Lucy Liu's", 97),
#  ('Claire Danes', 95),
#  ('Adele', 94),
#  ('Lucy Liu', 94),
#  ('Jennifer Lopez', 91),
#  ('RT @PerezHilton', 91),
#  ('Halle Berry', 86),
#  ('Jodie Foster', 80),
#  ('Julianne Moore', 79),
#  ('Amy', 77),
#  ('Kerry Washington', 71),
#  ('Amy Poehler', 70),
#  ('Jessica Chastain', 69),
#  ('Tina', 55),
#  ('Sofia Vergara', 49),
#  ('#redcarpet', 48),
#  ('Taylor Swift', 46),
#  ('Nicole Kidman', 44),
#  ('Jennifer Garner', 43),
#  ('Sienna Miller', 42),
#  ('Eva Longoria', 41),
#  ('Lena Dunham', 39),
#  ("Tina Fey's", 36),
#  ('Katniss', 35),
#  ('Zuhair Murad', 35),
#  ("Jennifer Lawrence's", 34),
#  ('Amanda Seyfried', 33),
#  ('#eredcarpet', 31),
#  ('Ben Affleck', 31),
#  ('Daniel Craig', 31),
#  ('Lea Michele', 30),
#  ('Kristen Wiig', 29),
#  ("Anne Hathaway's", 29),
#  ('Quentin', 29),
#  ('Megan Fox', 28),
#  ('Emily Blunt', 28),
#  ('Julia Roberts', 28),
#  ('RT', 27),
#  ("Jennifer Lopez's", 26),
#  ('Salma Hayek', 26),
#  ("Kerry Washington's", 23),
#  ('kate hudson', 23),
#  ('Nicole Richie', 22),
#  ('Rosario Dawson', 22),
#  ('Kristen Bell', 21),
#  ('halle berry', 21),
#  ('Miu Miu', 20),
#  ('Michelle Dockery', 20),
#  ('George Clooney', 20),
#  ("Taylor Swift's", 20),
#  ("Halle Berry's", 20),
#  ('Lucy', 20),
#  ('Amy Adams', 19),
#  ('Bradley Cooper', 19),
#  ('Kerry', 19),
#  ('Bill Clinton', 19),
#  ('RT @piersmorgan', 18),
#  ('Hugh Jackman', 18),
#  ('La veterana y favorita de la crítica', 18),
#  ('Maggie Smith se lleva el premio', 18),
#  ("Eva Longoria's", 18),
#  ('Naomi Watts', 17),
#  ('#BestDressed', 17),
#  ("Jessica Alba's", 17),
#  ('Will Ferrell', 17),
#  ('Tom Ford', 16),
#  ("Amy Poehler's", 16),
#  ('Jennifer', 16),
#  ('J.Lo', 16),
#  ('Quentin Tarantino', 16),
#  ('#bestdressed', 15),
#  ('Katharine McPhee', 14),
#  ('Lena', 14),
#  ("Jessica Chastain's", 13),
#  ('Marion Cotillard', 13),
#  ('J. Lo', 13),
#  ('Taylor', 13),
#  ('Oscar', 13),
#  ('Adam', 13),
#  ('Aww Lea Michele', 13),
#  ('J-Lo', 12),
#  ('RT @tomandlorenzo', 12),
#  ('Jessica', 12),
#  ('#RedCarpet', 12),
#  ('Elie Saab', 12),
#  ('Lucy Lui', 12),
#  ('Kate', 12),
#  ('Kristen', 12),
#  ('anne hathaway', 11),
#  ('Julianne Hough', 11),
#  ('Allison Williams', 11),
#  ('Anne', 11),
#  ('Jessica alba', 11),
#  ('Eva Longoria Stuns', 11),
#  ('Jeremy Irons', 11),
#  ('Halle', 10),
#  ('Hayden Panettiere', 10),
#  ('Katherine McPhee', 10),
#  ("Lena Dunham's", 10),
#  ('Selena Gomez', 10),
#  ('Helena Bonham Carter', 10),
#  ('Leonardo DiCaprio', 9),
#  ('Helen Mirren', 9),
#  ('Debra Messing', 9),
#  ("Julianne Moore's", 9),
#  ('Alexander McQueen', 9),
#  ('#gorgeous', 9),
#  ("Lea Michele's", 9),
#  ('Christoph Waltz', 9),
#  ('#katehudson', 9),
#  ('Eva', 9),
#  ('Catherine Zeta-Jones', 9),
#  ("Kristen Bell's", 9),
#  ("Rosario Dawson's", 9),
#  ("J. Lo's", 9),
#  ('J Lo', 9),
#  ("Kristen Wiig's", 9),
#  ("Lucy Lui's", 9),
#  ('Lea Michelle', 9),
#  ('Heidi Klum', 9),
#  ('elmer', 9),
#  ('vince vaughn', 9),
#  ("Jodie Foster's", 9),
#  ('@tomandlorenzo', 8),
#  ('Miranda Kerr', 8),
#  ('Zooey Deschanel', 8),
#  ('TinaFey', 8),
#  ('Poehler', 8),
#  ("Nicole Kidman's", 8),
#  ('Dior', 8),
#  ('James Cameron', 8),
#  ('Daniel Day Lewis', 8),
#  ('Daniel Day-Lewis', 8),
#  ('Don Cheadle', 8),
#  ('Catherine Zeta Jones', 8),
#  ("J-Lo's", 8),
#  ('#LucyLiu', 8),
#  ('Dear Beliebers', 8),
#  ('Rachel Weisz', 7),
#  ('Isla Fisher', 7),
#  ('#GG', 7),
#  ('#amypoehler', 7),
#  ('Selma Hayek', 7),
#  ('Maggie Smith', 7),
#  ('Michael Kors', 7),
#  ('Helena Bonham Carter   Dress 2013:', 7),
#  ("Claire Danes'", 7),
#  ('#JenniferLopez', 7),
#  ('#loveher', 7),
#  ('#werk', 7),
#  ('Lea', 7),
#  ('Tarantino', 7),
#  ('Debra', 7),
#  ('Lucy Lu', 7),
#  ('Congrats @jessicaalba @EvaLongoria', 7),
#  ('Paul Epworth', 7),
#  ('Yay Jessica', 7),
#  ("Sienna Miller's", 6),
#  ('@PerezHilton', 6),
#  ('Denzel', 6),
#  ('Kristin Wiig', 6),
#  ('Roberto Cavalli', 6),
#  ('Naeem Khan', 6),
#  ('Monique Lhuillier', 6),
#  ('Chastain', 6),
#  ('Jennifer Lopez @JLo', 6),
#  ('#AmyPoehler', 6),
#  ('Ann Hathaway', 6),
#  ('Jen', 6),
#  ('tina', 6),
#  ('Clare Danes', 6),
#  ('Ben', 6),
#  ('Kate Hudsons', 6),
#  ('Tommy Lee Jones', 6),
#  ('#omginsider', 6),
#  ('#jealous', 6),
#  ('Rosario', 6),
#  ('Claire', 6),
#  ('Jennifer Lopez -   ', 6),
#  ("Jennifer Lopez'", 6),
#  ('#JLo', 6),
#  ('Lo', 6),
#  ('Robert Pattinson', 6),
#  ('Lincoln', 6),
#  ('taylor swift', 6),
#  ('Kelly Osbourne', 6),
#  ('JLaw', 6),
#  ('Nah', 6),
#  ('Jodi Foster', 6),
#  ('Al Gore', 6),
#  ('Kevin Dior', 5),
#  ('Rob', 5),
#  ("Amanda Seyfried's", 5),
#  ('Sophia Vergara', 5),
#  ('#JenniferLawrence', 5),
#  ("Emily Blunt's", 5),
#  ('Hathaway', 5),
#  ('GQ Cover', 5),
#  ('Tina fey', 5),
#  ('Julianna Margulies', 5),
#  ('Bill Murray', 5),
#  ('amy', 5),
#  ('Donna Karan Atelier', 5),
#  ('Ang Lee', 5),
#  ('Connie Britton', 5),
#  ('Dennis Quaid', 5),
#  ('Fey', 5),
#  ('#jlo', 5),
#  ('Francesca Eastwood', 5),
#  ('Versace', 5),
#  ('Jessica Lange', 5),
#  ('Low Back Donna Karan Atelier Dress', 5),
#  ('@benaffleck', 5),
#  ('RT @tez_palmer', 5),
#  ('Kerry Washingtons', 5),
#  ("Eva longoria's", 5),
#  ('Helen Hunt', 5),
#  ('Paul Rudd', 5),
#  ('#homeland', 5),
#  ('Tina Faye', 5),
#  ('jennifer lawrence', 5),
#  ('Kate Hudson es Alexander', 5),
#  ('de MIS', 5),
#  ('#jenniferlopez', 5),
#  ("J Lo's", 5),
#  ("Scarlett O'Hara", 5),
#  ('#sopretty', 5),
#  ('Clinton', 5),
#  ("Kristin Wiig's", 5),
#  ('Gol', 5),
#  ('#worstdress', 5),
#  ('#JodieFoster', 5),
#  ('Jodie', 5),
#  ('Congrats Francisco Costa @CalvinKlein', 5),
#  ('#SofiaVergara', 4),
#  ('Zac Posen', 4),
#  ('Denzel Washington', 4),
#  ('#Adele  ', 4),
#  ('Lana Del Rey', 4),
#  ('#Eredcarpet', 4),
#  ('Rob Pattinson', 4),
#  ('#beautiful', 4),
#  ('Ewan McGregor', 4),
#  ("Sofia Vergara's", 4),
#  ("Jay Leno's", 4),
#  ('#JessicaChastain', 4),
#  ('Olivia Munn', 4),
#  ('Red Dress', 4),
#  ('Julianne', 4),
#  ("Ann Hathaway's", 4),
#  ('Johnny Depp', 4),
#  ('Sally Field', 4),
#  ('Tina Feys', 4),
#  ('Walgreens', 4),
#  ('Miranda', 4),
#  ('Wtf', 4),
#  ('tina fey', 4),
#  ('#spikedpunch', 4),
#  ('Leo DiCaprio', 4),
#  ('#Gorgeous', 4),
#  ('Leo', 4),
#  ('Giuliana', 4),
#  ('Halley Berry', 4),
#  ('WOWOWOWOWOWOWOWW Eva Longoria  ', 4),
#  ('Bill', 4),
#  ("Julianne Hough's", 4),
#  ('TNT te amamos att:', 4),
#  ('mafe', 4),
#  ('stephy y pipe', 4),
#  ('Givenchy', 4),
#  ("Salma Hayek's", 4),
#  ('Rob @   ', 4),
#  ('Joaquin Phoenix', 4),
#  ('#Cotillard', 4),
#  ('#Intouchables', 4),
#  ("Mel Gibson's", 4),
#  ('Mickey Mouse', 4),
#  ('velour sweatpants', 4),
#  ('JLo', 4),
#  ('Jlo', 4),
#  ('JESSICA ALBA', 4),
#  ('#JessicaAlba', 4),
#  ('bill clinton', 4),
#  ('Kristen Wig', 4),
#  ("Hillary Clinton's", 4),
#  ('Jennifer Lawrence &amp', 4),
#  ('Meryl', 4),
#  ('Jessica Chastain’s', 4),
#  ('megan fox', 4),
#  ('#girlcrush', 4),
#  ('Eddie Redmayne', 4),
#  ('LUCY LIU', 4),
#  ('Marie Antoinette', 4),
#  ("Lucy Lu's", 4),
#  ("lucy liu's", 4),
#  ('#LucyLui', 4),
#  ("lucy lui's", 4),
#  ('Schwarzenegger', 4),
#  ("Matt LeBlanc's", 4),
#  ('Michelle', 4),
#  ('Nina Dobrev', 4),
#  ('Sacha', 4),
#  ('Cohen', 4),
#  ('Ralph', 4),
#  ('#lenadunham', 4),
#  ('#fashionpolice', 4),
#  ('Glenn Close', 4),
#  ('Cecil B. DeMille', 4),
#  ('Jodie Fosters', 4),
#  ('Les Mis', 4),
#  ('Jennifer Gardner', 4),
#  ('Zooey Deschanel’s Cute Nails', 4),
#  ('Sienna Miller’s', 4),
#  ('#ModernFamily', 3),
#  ('Donna Karan', 3),
#  ("Helen Mirren's", 3),
#  ('#fashtag', 3),
#  ('Emmy', 3),
#  ('Jessica chastain', 3),
#  ('David', 3),
#  ('Kidman', 3),
#  ('Burberry', 3),
#  ('Nicole Ritchie', 3),
#  ('de Invencibles', 3),
#  ('J. LO', 3),
#  ('dkny', 3),
#  ('#hfpa http://t.co/4YnkaPWs', 3),
#  ('Anne #Hathaway', 3),
#  ('Stacey Keibler', 3),
#  ("Julianna Marguiles'", 3),
#  ('Xox💋', 3),
#  ('Sarah Hyland', 3),
#  ('http://t.co/ccotj3sr', 3),
#  ('#PGRedCarpet', 3),
#  ('#ERedCarpet', 3),
#  ('Claire Danes Looking', 3),
#  ('GetGlue', 3),
#  ('#hot', 3),
#  ('Alba', 3),
#  ('Sally', 3),
#  ('Dockery', 3),
#  ('#adele', 3),
#  ('#Sexy', 3),
#  ('Guiliana', 3),
#  ('God', 3),
#  ('#tinafey', 3),
#  ('Omg', 3),
#  ('Amy Pohler', 3),
#  ('Emily Blunt &amp', 3),
#  ("Loving Tina's", 3),
#  ('Jessica Rabbit', 3),
#  ('#amyadams', 3),
#  ('#funny', 3),
#  ("Rachel Weisz's", 3),
#  ('#miumiu', 3),
#  ('#omgInsider', 3),
#  ('halle berrys', 3),
#  ('Amy Poehler - Ladies', 3),
#  ('#myheroes', 3),
#  ('"Ang Lee', 3),
#  ('Amy P', 3),
#  ('Giorgio Armani', 3),
#  ('KateHudson', 3),
#  ("Omg Kate Hudson's", 3),
#  ('Kate hudson', 3),
#  ('Leonardo', 3),
#  ('Graziela Gems', 3),
#  ('Rona Pfeiffer', 3),
#  ('#TheHungerGames', 3),
#  ('LOL', 3),
#  ('Hayden', 3),
#  ('#kerrywashington', 3),
#  ('#HaymitchFashionPolice', 3),
#  ("Maggie Smith's", 3),
#  ('Ewan', 3),
#  ('Eva longoria', 3),
#  ('Eva Longorias', 3),
#  ('Julian Moore', 3),
#  ('#christophwaltz', 3),
#  ('#gamechange', 3),
#  ("Sarah Paulson's", 3),
#  ('#favorite', 3),
#  ("Allison Williams'", 3),
#  ('Mary Crawley', 3),
#  ('Sideboob', 3),
#  ('espectacular como siempre', 3),
#  ('Zac Posen Gown', 3),
#  ('Eva L', 3),
#  ('Mary', 3),
#  ('#EvaLongoria', 3),
#  ('Vanessa', 3),
#  ('Taylor Swifts', 3),
#  ('Darcy St. Fudge', 3),
#  ("Francesca Eastwood's", 3),
#  ('Hallie Berry', 3),
#  ('#Scandal', 3),
#  ('Raf Simons', 3),
#  ('Victor Garber', 3),
#  ('Thandie Newton', 3),
#  ('Que hueva', 3),
#  ('#thatdress', 3),
#  ('Gross', 3),
#  ('#paulrudd', 3),
#  ('@SalmaHayek', 3),
#  ("Kaley Cuoco's", 3),
#  ('Favorite Latina', 3),
#  ('Brody', 3),
#  ('#favoriteshow', 3),
#  ('mi', 3),
#  ('kutsi en', 3),
#  ('yoksa adi batsin kurenin', 3),
#  ('Hayden Paniettiere', 3),
#  ('Cranston', 3),
#  ('Zooey Deschanel Dazzles', 3),
#  ('#DowntonAbbey', 3),
#  ('#', 3),
#  ('Jennifer lopez', 3),
#  ("Ben Affleck's", 3),
#  ('#stunning', 3),
#  ('Beyonce', 3),
#  ('Michaels', 3),
#  ('#Fashionpolice', 3),
#  ('jlo', 3),
#  ('J-Lo’s', 3),
#  ('Barbie', 3),
#  ('Katniss Everdeen', 3),
#  ('RT @EHolmesWSJ', 3),
#  ('James Bond', 3),
#  ('#getitgirl', 3),
#  ('lea michele', 3),
#  ('Helena Bonham Carter   Dress', 3),
#  ('Benedict Cumberbatch', 3),
#  ('Ricky Gervais', 3),
#  ('Kevin Costner', 3),
#  ('Spielberg', 3),
#  ('@MichNovi', 3),
#  ('#fashionfav', 3),
#  ('Will Ferrel', 3),
#  ('Preshow', 3),
#  ('Kristin', 3),
#  ("Giuliana Rancic's", 3),
#  ('#flawless', 3),
#  ('Dang', 3),
#  ("Will Ferrell's", 3),
#  ("Hugh Jackman's", 3),
#  ('#أزياء', 3),
#  ('Rosado de Laurent Perrier', 3),
#  ('Mi favorito', 3),
#  ('Jennifer lawrence', 3),
#  ('Kate Hudson -   ', 3),
#  ('Jenn', 3),
#  ('kristen', 3),
#  ('Ariel Winter', 3),
#  ('Si por', 3),
#  ('Max Greenfield', 3),
#  ('Unchained', 3),
#  ('#KristenBell', 3),
#  ("Megan Fox's", 3),
#  ('Jennifer Lawrence keepin', 3),
#  ('Emily', 3),
#  ('#blargh', 3),
#  ('Anne Hathaway una de mis favoritas y gano', 3),
#  ('Gl', 3),
#  ("Justin Bieber's", 3),
#  ("Jeremy Iron's", 3),
#  ('Maria Von Trapp', 3),
#  ('Louie CK', 3),
#  ('Deborah', 3),
#  ('Joey', 3),
#  ("Marie Antoinette's", 3),
#  ('Favorito', 3),
#  ('#Bert', 3),
#  ('Don', 3),
#  ('Grace', 3),
#  ('Stallone', 3),
#  ('Arnold', 3),
#  ('#Oscar como Mejor Película Extranjera', 3),
#  ('#lovethedress', 3),
#  ("Jen Lawrence's", 3),
#  ('Down Jennifer Lopez', 3),
#  ('Dunham', 3),
#  ("George Clooney's", 3),
#  ('Rusell Crowe', 3),
#  ('Brett Favre', 3),
#  ('Perdió Zoey Deschanel', 3),
#  ("Michael J. Fox's", 3),
#  ('Robert Downey Jr.', 3),
#  ("Michael J Fox's", 3),
#  ('Lifetime Achievement', 3),
#  ('#myfavorite', 3),
#  ('Bugsy Malone', 3),
#  ('Little Man Tate', 3),
#  ('Nell', 3),
#  ('Adams', 3),
#  ('Mel Gibson no te caigas', 3),
#  ('RT @cinema21', 3),
#  ('Jodi', 3),
#  ('Spielberg parace', 3),
#  ('ser el favorito', 3),
#  ('halle', 3),
#  ('#HalleBerry', 3),
#  ('@johnnywujek http://t.co/Bi4mAAyw', 3),
#  ('Jay Leno', 3),
#  ('#Girls', 3),
#  ('lena dunham', 3),
#  ('this Glenn Close GIF', 3),
#  ('#BenAffleck', 3),
#  ('http://t.co/qnek2e3F #', 3),
#  ("Jennifer Garner's", 3),
#  ("Jennifer Gardner's", 3),
#  ('Hugh', 3),
#  ("Michelle Dockery's", 3),
#  ('Jessica C', 3),
#  ('#RevistaBillboard Adele', 3),
#  ('#favoritesontheredcarpet', 3),
#  ('#Lincoln', 3),
#  ("Daniel Day Lewis'", 3),
#  ('Zooey Desc', 3),
#  ('Robert Downey Jr', 3),
#  ('JULIA ROBERTS', 3),
#  ('Lancome Ambassadress', 3),
#  ('#girlpower', 3),
#  ("Tina n Amy's", 3),
#  ('#GIRLS', 3),
#  ('#meganfox', 3),
#  ('WOW Eva longorias dress @EvaLongoria', 3),
#  ('#inlove', 3),
#  ('Werk @kerrywashington', 2),
#  ('Natalie Morales', 2),
#  ('pfavor', 2),
#  ('não posso perder esse evento', 2),
#  ('#lovingit', 2),
#  ('Qué grandisimo que es por', 2),
#  ('http://t.co/P9QPjfUP', 2),
#  ('Dame Helen Mirren', 2),
#  ('jLO', 2),
#  ('Loving Kerry', 2),
#  ("Looooove Anne Hathaway's", 2),
#  ('#SofiaVergara esta ufff', 2),
#  ('Ricky Gervais wd', 2),
#  ('MT @piersmorgan', 2),
#  ('#nbc', 2),
#  ('#AnnHathaway', 2),
#  ("KRISTEN BELL'S", 2),
#  ('#marioncotillard', 2),
#  ('Meryl Streep', 2),
#  ('#tyle', 2),
#  ('Nicole Kidmans', 2),
#  ('#BiggestFan', 2),
#  ('vestido da Sofia Vergara', 2),
#  ('mas nada demais tb', 2),
#  ('Jessica Chastain/', 2),
#  ('RT @deepa_k', 2),
#  ('Amy/Tina', 2),
#  ('Keri washington', 2),
#  ('#helenmirren', 2),
#  ('#AwardsSeason', 2),
#  ('Dokery', 2),
#  ('#ThatisAll', 2),
#  ('Sarah Paulson', 2),
#  ('Sofía Vergara', 2),
#  ('#Burberry', 2),
#  ('salma hayek oldu', 2),
#  ('bu kadın giyinmesini', 2),
#  ("John Ham's", 2),
#  ("L'Wren Scott 2", 2),
#  ('Dior 4', 2),
#  ('Stella Mcart', 2),
#  ('#acting', 2),
#  ('sofia vargara', 2),
#  ('Julie Bowen', 2),
#  ('#calvinklein', 2),
#  ('#lazy', 2),
#  ('Hayden Panniterre', 2),
#  ('Marshall', 2),
#  ('#oneofakind', 2),
#  ('RT @clarabela', 2),
#  ("Julianna Margulies'", 2),
#  ('Sofia Vagara', 2),
#  ('@peoplemag Julianne Moore', 2),
#  ('George klooneys gf', 2),
#  ('FAV si estás viendo los', 2),
#  ('Julianna Marguelies', 2),
#  ('De los mejores', 2),
#  ('#AlfombraRojaE', 2),
#  ('Wow Jessica Chastain looks', 2),
#  ('Legolas', 2),
#  ('Thatcher', 2),
#  ('Giuliana Rancic', 2),
#  ('Oriett Domenech', 2),
#  ('Jullianne Hough', 2),
#  ('LV', 2),
#  ('Loving Naomi Watts', 2),
#  ('Fitz', 2),
#  ('Hellloo Salma', 2),
#  ("Nicole Richie's", 2),
#  ('Jackman y', 2),
#  ('#makingmyjawdrop', 2),
#  ('Jon Hamm', 2),
#  ('Stunning Naomi Watts', 2),
#  ('#bestdressed "', 2),
#  ('Aziz Ansari', 2),
#  ('Cottilard', 2),
#  ('Watts', 2),
#  ('John Hamm', 2),
#  ('#Downtonabbey', 2),
#  ('Nicole R', 2),
#  ('Bradley cooper', 2),
#  ('#LoveIt', 2),
#  ('#greatdressthough', 2),
#  ('Wow @SofiaVergara', 2),
#  ("Zosia Mamet's", 2),
#  ('Alyssa Sutter', 2),
#  ("Sophia Vergara's", 2),
#  ('RT @TiffanyAndCo', 2),
#  ('#MyTop5FashionFavs', 2),
#  ('@juliannarancic', 2),
#  ('Favoritas', 2),
#  ('eredcarpet', 2),
#  ('sofia', 2),
#  ('#GiulianaRancic', 2),
#  ('Reem', 2),
#  ('Lucy Luis', 2),
#  ('far - lucy lu', 2),
#  ('#myfavoritewomen', 2),
#  ('QT @FashionweekNYC', 2),
#  ('Julianna Marguiles', 2),
#  ('Que mujeres hermosas hay en el  ', 2),
#  ('Que Vestidos', 2),
#  ('#goddess', 2),
#  ("#LucyLiu's", 2),
#  ('Nana Greenbergs', 2),
#  ('Michael Cinco', 2),
#  ('#PinoyPride', 2),
#  ('#baddress', 2),
#  ('#badhair', 2),
#  ('Stacy Keibler', 2),
#  ('#justsaying', 2),
#  ('#NYC', 2),
#  ('Tom', 2),
#  ("Lucy Luis's", 2),
#  ('RT @JasmineThangg', 2),
#  ('Anne Hatheway', 2),
#  ('Sofia', 2),
#  ('#hfpa http://t.co/oK8Aq1X0', 2),
#  ('Hayden panettiere', 2),
#  ('Leo Dicaprio', 2),
#  ('Jennifer Lawerence', 2),
#  ('#zuhairmurad', 2),
#  ('Anne Hathaway Fresh', 2),
#  ('#eredcarpet Carpet', 2),
#  ('Sofia vergara', 2),
#  ('#eRedCarpet', 2),
#  ('Julianne Moore RT', 2),
#  ('#dressoff', 2),
#  ('JessicaChastain', 2),
#  ('Jason statham', 2),
#  ('Ahh @MissKellyO', 2),
#  ('Shazam', 2),
#  ("Julianna Moore's", 2),
#  ('Tom Ford Dress', 2),
#  ('Andy Reid', 2),
#  ('importa nada de los  ', 2),
#  ('#Patriots', 2),
#  ('Guilliana', 2),
#  ("Loving Stacy Keibler's", 2),
#  ('Lea luce preciosa', 2),
#  ('Otra de mis favoritas de la noche', 2),
#  ('Kelly', 2),
#  ('#amypoeler', 2),
#  ("Natalie Morales'", 2),
#  ('Savannah Guthrie', 2),
#  ('Mis favoritas', 2),
#  ('Amanda Seyfried y Kate Hudson', 2),
#  ('Taylor Swift 1', 2),
#  ("Love Tina's", 2),
#  ('#awardseason', 2),
#  ('Julianna Hough', 2),
#  ('sienna millers dress', 2),
#  ('Tengo mis favoritos para hoy', 2),
#  ("Omg Tina's", 2),
#  ('#weddingworthy', 2),
#  ('#likeafinewine', 2),
#  ('Julianna Margulies:', 2),
#  ('#notlikesheeverisnt', 2),
#  ('Nic Kidman', 2),
#  ('#theend  http://t.co/gOWNC66B', 2),
#  ('JENNIFER', 2),
#  ("LOVE Amy Adams'", 2),
#  ("Albert Finney's", 2),
#  ('Omg TINA', 2),
#  ('Globosdeoro', 2),
#  ('#ZeroDarkThirty y los', 2),
#  ('#miserables', 2),
#  ("Amy P's", 2),
#  ('#SiennaMiller', 2),
#  ("Loving Amy's", 2),
#  ("Tina Fey'S", 2),
#  ('Damn Helen Mirren', 2),
#  ('#Dreamgirl', 2),
#  ('#familyguy', 2),
#  ('Hasta este momento', 2),
#  ('Werq', 2),
#  ('Olivia munn', 2),
#  ('Nichole Richie', 2),
#  ('Naeem khan', 2),
#  ('Dayummm Tina Fey', 2),
#  ('Beverly Hilton de Los Ángeles', 2),
#  ('Cuéntenos', 2),
#  ('Tina Fays', 2),
#  ('DAMNNNN Rachel Weisz', 2),
#  ('#sheneverswears', 2),
#  ('Dax Shepard', 2),
#  ('Ini yg di E', 2),
#  ('pada Gorgeous2 smua', 2),
#  ('Fufufu', 2),
#  ("Tina Fey's Dress", 2),
#  ('bori bori', 2),
#  ('Taylor Bitch', 2),
#  ("Margaery Tyrell's", 2),
#  ('#awardshow', 2),
#  ('#myfav', 2),
#  ("Amy Adam's", 2),
#  ('Hachi-machi', 2),
#  ('Jessica Rabbit-esque', 2),
#  ('Amy Poehlers', 2),
#  ("TINA FEY'S", 2),
#  ('#badumtss', 2),
#  ('Hilary Swank', 2),
#  ('AnneHathaway', 2),
#  ('Halle Berry - more', 2),
#  ('mis favoritas', 2),
#  ('Zooey Deschanel y Anne Hathaway', 2),
#  ('Tina y Amy', 2),
#  ('sean mas cheveres', 2),
#  ('J.Lo  ', 2),
#  ('http://t.co/R8jUa1nV', 2),
#  ('lovee Tina Feys dress', 2),
#  ('#worstdressed', 2),
#  ('Reedus', 2),
#  ('Les Misérables’', 2),
#  ('bewby neckline', 2),
#  ('Tina F', 2),
#  ('mandy patinkin', 2),
#  ('#newfavoritegame', 2),
#  ('omg luv', 2),
#  ('Joe', 2),
#  ('Muchos alucinaran con el atuendo de Anne Hathaway', 2),
#  ('lo siento', 2),
#  ("Loving Kate Hudson's", 2),
#  ('KATE HUDSON', 2),
#  ('Pi', 2),
#  ('donna karan', 2),
#  ('Bradley cooper dame un hijo', 2),
#  ('#fridaygirltv', 2),
#  ('#favoritepeople', 2),
#  ('Richard Gere', 2),
#  ('Carrick', 2),
#  ('#Werk', 2),
#  ('Leo #', 2),
#  ('Anne Hathaway ♥ RT', 2),
#  ('Anne Hathaway y Sandra Bullock', 2),
#  ('mis actrices favoritas', 2),
#  ('No hay quien las supere"', 2),
#  ('Freaken', 2),
#  ('Lea  &lt;3', 2),
#  ('Jennifer Lawrence y Sofia Vergara mis favoritas', 2),
#  ('Rebound', 2),
#  ('Amy Poeler', 2),
#  ('Lawrence', 2),
#  ('OHMYGOD KATE HUDSON GIVE', 2),
#  ('Alexis Carrington', 2),
#  ('the Flash Gordon', 2),
#  ('hoy especialmente espectacular', 2),
#  ('y al lado de Bradley Cooper', 2),
#  ('#af', 2),
#  ('#AmyPohler', 2),
#  ('TeamRhetoric', 2),
#  ('Cinna', 2),
#  ('Abe Lincoln', 2),
#  ('#whoknew', 2),
#  ('Christolph Waltz', 2),
#  ('Hudson', 2),
#  ('#StilettoGG', 2),
#  ('Amy Poelher', 2),
#  ('Congrats C Dub', 2),
#  ('Christoph', 2),
#  ('#besidesheath', 2),
#  ('#prettydress', 2),
#  ('Tommy', 2),
#  ('christoph Waltz', 2),
#  ('E.T.', 2),
#  ('#LeonardoDiCaprio', 2),
#  ('Genial retransmisión', 2),
#  ('Yessss', 2),
#  ('Mi pareja favorita de los', 2),
#  ('Daniel Craig y Rachel Weisz http://t.co/2XTCMpCg', 2),
#  ('#TinaFey', 2),
#  ('kate', 2),
#  ('#STYLAMERICAN', 2),
#  ('Blake', 2),
#  ('#parenttrap', 2),
#  ('Mandy Patinkin', 2),
#  ('#KerryWashington', 2),
#  ('no esta maggie smith', 2),
#  ('quiero que recoja su premio tranformandose en gato por', 2),
#  ('SOFIA VERGARA', 2),
#  ('#ChristophWaltz', 2),
#  ('Lucy Lieu', 2),
#  ('Nicole Richies', 2),
#  ('Omgg Kate Hudson dress', 2),
#  ('Jennifer Lawrence en Christian Dior Couture', 2),
#  ('Ben Afflecks', 2),
#  ('#WTF', 2),
#  ('Halle Berrys', 2),
#  ('Amy poehler', 2),
#  ('#faveactressever', 2),
#  ('Eu assistindo', 2),
#  ('nas minhas séries favoritas', 2),
#  ('SARAH', 2),
#  ('#girlcrushin', 2),
#  ('fashtag RT', 2),
#  ('Kristen Wigg', 2),
#  ('batman geesh', 2),
#  ('PEEP KERRY', 2),
#  ('#smgirlfriends @DowntonAbbey', 2),
#  ('#alittlejealous', 2),
#  ('La veterana y favorita de la crítica especializada Maggie Smith se lleva el premio',
#   2),
#  ('#wantwantwant', 2),
#  ('Zuhair Murad Gorgeous', 2),
#  ('Byk bgt yg pake nude dress', 2),
#  ('RT @wisnude Julianne Hough', 2),
#  ('bien merecido Maggie Smith', 2),
#  ('http://t.co/lqIjno1p', 2),
#  ('Taylor Swift Gorgeous On The Red Carpet', 2),
#  ('redcarpet', 2),
#  ('Ed Hardy', 2),
#  ('Sofia Veraga', 2),
#  ('#notquite', 2),
#  ('moro de guandule', 2),
#  ('Es Maggie Smith', 2),
#  ('#classyshit', 2),
#  ('Honors', 2),
#  ('Kerri Washington', 2),
#  ('Christopher Waltz', 2),
#  ('the Evil Queen', 2),
#  ('omg @jlo', 2),
#  ('Jeremy Renner', 2),
#  ('Fah-shon', 2),
#  ('Eva longoria dress &amp', 2),
#  ('#DonnaKaranAtelier', 2),
#  ('#emeraldalicious', 2),
#  ('#watchfordresses', 2),
#  ('Maggie smith', 2),
#  ('La mejor miniserie para Game Change', 2),
#  ('Omg the', 2),
#  ('Nicole', 2),
#  ("Loving Eva's", 2),
#  ('#myfave', 2),
#  ('Lol jlo RT @vrock112', 2),
#  ('Hatfield', 2),
#  ('McCoys', 2),
#  ('quando os vejo', 2),
#  ('#loveit #legsfordays', 2),
#  ('best!“@WorldMcQueen', 2),
#  ('Angie', 2),
#  ('Kaley Cuoco', 2),
#  ('mulberry lippy', 2),
#  ('GameChange', 2),
#  ('Diulang tadi salah', 2),
#  ('cantik banget ini Megan', 2),
#  ("Francesa Eastwood's", 2),
#  ('Michael', 2),
#  ('Michael J Fox', 2),
#  ('Tracy Pollan', 2),
#  ('#HalleyBerry', 2),
#  ('jennifer', 2),
#  ('Wow Eva Longoria!', 2),
#  ('ALLYN   DESIGNER NHA', 2),
#  ('Anne Hathway', 2),
#  ("Sienna  Miller's", 2),
#  ('richard desde venezuela', 2),
#  ('Jessica Lange por', 2),
#  ('SIENNA MILLER', 2),
#  ('@marykitchen @', 2),
#  ('Jajaja', 2),
#  ('Wow Julianne Moore', 2),
#  ('Zooey', 2),
#  ('#Favoritos', 2),
#  ('#AlfombraRoja', 2),
#  ('Jullian Moore', 2),
#  ("nicole kidman's", 2),
#  ('Mi favorito de esta noche Quentin Tarantino', 2),
#  ('luv luv luv', 2),
#  ('barbie', 2),
#  ('#memories', 2),
#  ('#barbiedress', 2),
#  ('Sienna miller', 2),
#  ("Love Julianne Moore's", 2),
#  ('#tomfordress', 2),
#  ('Charlie', 2),
#  ('#asingleman', 2),
#  ('#nooffence', 2),
#  ('tuvo su baile el año', 2),
#  ('#idol', 2),
#  ('Julian More es una de las pocas actrices que esta en contra', 2),
#  ('al actuar', 2),
#  ("Catherine Zeta-Jones'", 2),
#  ('#Gossip', 2),
#  ("Catherine Zeta Jones'", 2),
#  ('#JulianneMoore ...', 2),
#  ('#amya http://t.co/gks0BgPX', 2),
#  ("Juliane Moore levando '", 2),
#  ('http://t.co/30Wc90ol', 2),
#  ('Bangun pagi dgn berita tentang  ', 2),
#  ('akan selalu ada', 2),
#  ('Tapi harusnya tidak terjadi pd seorang Sienna Miller', 2),
#  ("Catherine Zeta-Jones's", 2),
#  ('#flowerpower', 2),
#  ('#CatherineZetaJonesDouglas', 2),
#  ('Catherine Zeta-Jones_is', 2),
#  ('favourites Maggie Smith', 2),
#  ('sienna miller', 2),
#  ('#RT', 2),
#  ('para eu poder', 2),
#  ('Huff', 2),
#  ('Bonham Carter', 2),
#  ('#soexcited', 2),
#  ('#dilfs', 2),
#  ('Y Kelly O. es de Fashion Police', 2),
#  ('RT @RomanMoralesR', 2),
#  ('Sofy Vergara', 2),
#  ('Catherine zeta jones', 2),
#  ('Barbara', 2),
#  ('Peyton Manning', 2),
#  ('Julianna Moore', 2),
#  ('#lesliefremar', 2),
#  ('#JulianneMoore', 2),
#  ('RT @laurena11', 2),
#  ('pero lo mato con el peinado', 2),
#  ('es un @givenchy mi reina', 2),
#  ('Que paso ahi..', 2),
#  ('Hayden Panettier', 2),
#  ('#Adele', 2),
#  ('#favouriteawardshow', 2),
#  ('RT @DianaMadison', 2),
#  ('#hungergamesauction', 2),
#  ('Ohmygod Taylor', 2),
#  ('Angelina', 2),
#  ('Julianne Moore menang', 2),
#  ("Tom Ford's", 2),
#  ('hayden', 2),
#  ('nicole kidman', 2),
#  ('emily blunt', 2),
#  ('#Insider', 2),
#  ('Stacey keiblers', 2),
#  ('a Tom Ford', 2),
#  ('#WorstDressed', 2),
#  ('Katherine Zeta Jones', 2),
#  ('#raismanprobs', 2),
#  ('@NETAPORTER Julianne Moore', 2),
#  ('Matt Bellamy', 2),
#  ('Eredcarpet', 2),
#  ('Dayyyam Tina Fey', 2),
#  ('Tangerine', 2),
#  ('Jlo RT', 2),
#  ('#gorgeousman', 2),
#  ('Catherine Z-J', 2),
#  ('están haciendo favor de tuitear lo que está pasando', 2),
#  ('#twitter', 2),
#  ('jessica chastain', 2),
#  ('rosario dawsons dress', 2),
#  ('maggie smith', 2),
#  ('Ohhhhhh Rosario Dawson', 2),
#  ('haganse un', 2),
#  ('#somanysnacks', 2),
#  ('#smgirlfriends', 2),
#  ("Cody Horn's", 2),
#  ('Tina Fey + Amy Poehler', 2),
#  ('Anne Hathaway por', 2),
#  ('hey rosario dawson', 2),
#  ('judy jetson', 2),
#  ("juliana Margulies's", 2),
#  ('bello el vestido', 2),
#  ('Rosario Dawson se apunta al azul', 2),
#  ('como Jessica Chastain', 2),
#  ('y con un', 2),
#  ('contarán los  ...', 2),
#  ('Yo mientras la paso mal por ustedes esta noche', 2),
#  ('Yep Salma Hayek', 2),
#  ('Alwayslooksfantastic', 2),
#  ('Omg Selma Hayek', 2),
#  ('#workthemcurves', 2),
#  ('#ick', 2),
#  ...]
